# %%
import numpy as np
from sklearn.datasets import load_diabetes

# %%
X,y=load_diabetes(return_X_y=True)

# %%
X.shape
# Out:
# (442, 10)

# %%
y
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (353, 10)
# (89, 10)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(X_test)

# %%
y_pred
# Out:
# array([154.1213881 , 204.81835118, 124.93755353, 106.08950893,
#        258.5348576 , 256.3310074 , 118.75087616, 119.52440696,
#        101.50816735, 190.54048661, 141.70656811, 172.51883961,
#        174.33861649, 134.80942706, 294.13994537,  94.11798038,
#        211.97059795, 156.49579378, 134.21000428, 119.62664644,
#        148.87842251, 165.00873409, 151.10021038, 176.04063756,
#        133.27769647, 221.29555392, 197.17324941,  96.1577688 ,
#         50.26012711, 230.48580317, 242.06073866, 114.11129218,
#         67.07532417,  94.52943825, 201.21415375, 167.05136201,
#        159.881268  , 192.78746659, 114.49551325, 233.48234551,
#        140.82563045, 121.0680409 , 192.27480772, 191.12738845,
#        179.16865788, 148.34935601, 163.47414622, 276.81647884,
#        100.17926432, 164.10555298, 255.80762189, 136.9466204 ,
#        152.37503699, 107.92237882, 194.21924678,  77.34670792,
#        118.50482479,  68.38335763, 154.29258529, 162.48840259,
# ...

# %%
y_test
# Out:
# array([ 73., 233.,  97., 111., 277., 341.,  64.,  68.,  65., 178., 142.,
#         77., 244., 115., 258.,  87., 220.,  86.,  74., 132., 136., 220.,
#         91., 235., 148., 317., 131.,  84.,  65., 217., 306.,  79., 158.,
#         54., 123., 174., 237., 212., 179., 281., 187., 200.,  68., 163.,
#        141., 202., 178., 242.,  47., 131., 243., 142., 200.,  89., 232.,
#         55., 253., 128., 104., 184., 110., 198.,  81., 195., 150.,  63.,
#        151., 233., 178.,  84., 237., 109., 131., 252., 200., 160., 200.,
#         51., 111.,  77., 201.,  88.,  78., 243., 268.,  55., 270., 288.,
#         91.])

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.4399338661568968

# %%
lr.intercept_
# Out:
# np.float64(151.88331005254167)

# %%
lr.coef_
# Out:
# array([  -9.15865318, -205.45432163,  516.69374454,  340.61999905,
#        -895.5520019 ,  561.22067904,  153.89310954,  126.73139688,
#         861.12700152,   52.42112238])

# %%
# !git rm --cached filename.ext
# Out:
# fatal: pathspec 'filename.ext' did not match any files

# %%
# !git rm --cached multipleLR.ipynb
# Out:
# rm 'multipleLR.ipynb'

# %%
# !git commit -m "Remove  from repository"
# Out:
# [main 2ee33d7] Remove  from repository
#  1 file changed, 23 deletions(-)
#  delete mode 100644 multipleLR.ipynb

# %%
# !git push origin main
# Out:
# To https://github.com/TANUSHRI-BHISE/LinearRegression.git
#    2f34c7a..2ee33d7  main -> main

# %%
# !git init
# Out:
# Reinitialized existing Git repository in C:/Users/TANUSHREE/Desktop/campusx/dsalgo/.git/

# %%
# !git add .

# %%
# !git commit -m "Initial commit"
# Out:
# [main 31d43bb] Initial commit
#  1 file changed, 23 insertions(+)
#  create mode 100644 multipleLR.ipynb

# %%
# !git remote add origin https://github.com/TANUSHRI-BHISE/LinearRegression.git
# Out:
# error: remote origin already exists.

# %%
# !git remote -v
# Out:
# origin	https://github.com/TANUSHRI-BHISE/LinearRegression.git (fetch)
# origin	https://github.com/TANUSHRI-BHISE/LinearRegression.git (push)

# %%
# !git add .

# %%
# !git commit -m "Update repository with new files"
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
# !git branch -M main

# %%
# !git push -u origin main
# Out:
# branch 'main' set up to track 'origin/main'.
# To https://github.com/TANUSHRI-BHISE/LinearRegression.git
#    2ee33d7..31d43bb  main -> main

# %%
git rm --cached multipleLR.ipynb
# Out:
#   Cell In[36], line 1
#     git rm --cached multipleLR.ipynb
#         ^
# SyntaxError: invalid syntax

# %%
# !git rm --cached multipleLR.ipynb
# Out:
# rm 'multipleLR.ipynb'

# %%
# !git commit -m "Remove  from repository"
# Out:
# [main 1b52981] Remove  from repository
#  1 file changed, 23 deletions(-)
#  delete mode 100644 multipleLR.ipynb

# %%
# !git push origin main
# Out:
# To https://github.com/TANUSHRI-BHISE/LinearRegression.git
#    31d43bb..1b52981  main -> main

# %%
# !git add multipleLR.ipynb

# %%
# !git commit -m "Add new notebook: YourNewNotebook.ipynb"
# Out:
# [main 7caafa3] Add new notebook: YourNewNotebook.ipynb
#  1 file changed, 23 insertions(+)
#  create mode 100644 multipleLR.ipynb

# %%
# !git push origin main
# Out:
# To https://github.com/TANUSHRI-BHISE/LinearRegression.git
#    1b52981..7caafa3  main -> main
