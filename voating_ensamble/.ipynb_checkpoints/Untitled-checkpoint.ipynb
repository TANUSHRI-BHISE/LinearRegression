# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('HousingData.csv')

# %%
df.shape
# Out:
# (506, 14)

# %%
X=df.iloc[:,0:14]
X = X.fillna(0)
y=df.iloc[:,-1]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score

# %%
lr=LinearRegression()
dt=DecisionTreeRegressor()
svr=SVR()
estimators=[('lr',lr),('dt',dt),('svr',svr)]
for estimator in estimators:
    scores=cross_val_score(estimator[1],X,y,scoring='r2',cv=10)
    print(estimator[0],np.round(np.mean(scores),2))
# Out:
# lr 1.0
# dt 1.0
# svr -0.39

# %%
from sklearn.ensemble import VotingRegressor

# %%
vr=VotingRegressor(estimators)
scores=cross_val_score(vr,X,y,scoring='r2',cv=10)
print("voating regressor",np.round(np.mean(scores),2))
# Out:
# voating regressor 0.84

# %%
for i in range(1,4):
    for j in range(1,4):
        for k in range(1,4):
            vr=VotingRegressor(estimators,weights=[i,j,k])
            scores=cross_val_score(vr,X,y,scoring='r2',cv=10)
            
            
           
            print('for i={},j={},k={}'.format(i,j,k),np.round(np.mean(scores),2))
# Out:
# for i=1,j=1,k=1 0.84
# for i=1,j=1,k=2 0.65
# for i=1,j=1,k=3 0.5
# for i=1,j=2,k=1 0.91
# for i=1,j=2,k=2 0.78
# for i=1,j=2,k=3 0.65
# for i=1,j=3,k=1 0.94
# for i=1,j=3,k=2 0.84
# for i=1,j=3,k=3 0.74
# for i=2,j=1,k=1 0.91
# for i=2,j=1,k=2 0.78
# for i=2,j=1,k=3 0.65
# for i=2,j=2,k=1 0.94
# for i=2,j=2,k=2 0.84
# for i=2,j=2,k=3 0.74
# for i=2,j=3,k=1 0.96
# for i=2,j=3,k=2 0.89
# for i=2,j=3,k=3 0.8
# for i=3,j=1,k=1 0.94
# for i=3,j=1,k=2 0.85
# for i=3,j=1,k=3 0.74
# for i=3,j=2,k=1 0.96
# for i=3,j=2,k=2 0.89
# for i=3,j=2,k=3 0.8
# for i=3,j=3,k=1 0.97
# for i=3,j=3,k=2 0.91
# for i=3,j=3,k=3 0.84

# %%
dt1=DecisionTreeRegressor(max_depth=1)
dt2=DecisionTreeRegressor(max_depth=3)
dt3=DecisionTreeRegressor(max_depth=5)
dt4=DecisionTreeRegressor(max_depth=7)
dt5=DecisionTreeRegressor(max_depth=None)
estimators=[('dt1',dt1),('dt2',dt2),('dt3',dt3),('dt4',dt4),('dt5',dt5)]

# %%
for estimator in estimators:
    scores=cross_val_score(estimator[1],X,y,scoring='r2',cv=10)
    print(estimator[0],np.round(np.mean(scores),2))
# Out:
# dt1 0.06
# dt2 0.91
# dt3 0.99
# dt4 1.0
# dt5 1.0

# %%
vr=VotingRegressor(estimators)
scores=cross_val_score(vr,X,y,scoring='r2',cv=10)
print("voating regressor",np.round(np.mean(scores),2))
# Out:
# voating regressor 0.95
