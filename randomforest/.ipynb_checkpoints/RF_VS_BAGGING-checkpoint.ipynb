# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification
from sklearn.ensemble import BaggingClassifier,RandomForestClassifier
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %%
X,y=make_classification(n_features=5,n_redundant=0,n_informative=5,n_clusters_per_class=1)

# %%
df=pd.DataFrame(X,columns=['col1','col2','col3','col4','col5'])
df['target']=y
print(df.shape)
df.head()
# Out:
# (100, 6)
#        col1      col2      col3      col4      col5  target
# 0  1.120908  0.229893  2.159189  0.727666 -1.152908       1
# 1 -3.669979  1.632809 -0.494249  1.822777 -1.495945       0
# 2  0.209880 -1.877296 -0.016417 -2.973759 -2.493739       1
# 3  0.919533 -0.496357  1.276946 -0.699096 -0.356018       1
# 4  0.313653  0.010605  1.200627  2.420098 -2.899149       0

# %%
bag=BaggingClassifier(max_features=2)

# %%
bag.fit(df.iloc[:,:5],df.iloc[:,-1])
# Out:
# BaggingClassifier(max_features=2)

# %%
plt.figure(figsize=(12,12))
plot_tree(bag.estimators_[0])
plt.show()
#in bagging only 2 colums are selected  at each level hence tree level sampling

# %%
rf=RandomForestClassifier(max_features=2)
rf.fit(df.iloc[:,:5],df.iloc[:,-1])
# Out:
# RandomForestClassifier(max_features=2)

# %%
plt.figure(figsize=(12,12))
plot_tree(rf.estimators_[0])
plt.show()
#in random forest at each node we select two columnas randomly so any 2 columns may get selected hence its nodel level sampling

# %%
# !git add .

# %%
# !git commit -m "my work"
# Out:
# [main 1422722] my work
#  2 files changed, 12 insertions(+)
#  create mode 100644 randomforest/.ipynb_checkpoints/RF_VS_BAGGING-checkpoint.ipynb
#  create mode 100644 randomforest/RF_VS_BAGGING.ipynb

# %%
# !git push origin main
# Out:
# To https://github.com/TANUSHRI-BHISE/LinearRegression.git
#    8887697..1422722  main -> main
