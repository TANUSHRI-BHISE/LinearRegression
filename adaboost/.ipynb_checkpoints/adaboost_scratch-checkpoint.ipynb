# %%
import pandas as pd
import numpy as np
from mlxtend.plotting import plot_decision_regions
# Out:
# C:\Users\TANUSHREE\AppData\Roaming\Python\Python313\site-packages\pandas\core\computation\expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.10.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
df=pd.DataFrame()

# %%
df['X1']=[1,2,3,4,5,6,6,7,9,9]
df['X2']=[5,3,6,8,1,9,5,8,9,2]
df['label']=[1,1,0,1,0,1,0,1,0,0]

# %%
df
# Out:
#    X1  X2  label
# 0   1   5      1
# 1   2   3      1
# 2   3   6      0
# 3   4   8      1
# 4   5   1      0
# 5   6   9      1
# 6   6   5      0
# 7   7   8      1
# 8   9   9      0
# 9   9   2      0

# %%
import seaborn as sns
sns.scatterplot(x=df['X1'],y=df['X2'],hue=df['label'])
# Out:
# <Axes: xlabel='X1', ylabel='X2'>

# %%
df['weights']=1/df.shape[0]

# %%
df
# Out:
#    X1  X2  label  weights
# 0   1   5      1      0.1
# 1   2   3      1      0.1
# 2   3   6      0      0.1
# 3   4   8      1      0.1
# 4   5   1      0      0.1
# 5   6   9      1      0.1
# 6   6   5      0      0.1
# 7   7   8      1      0.1
# 8   9   9      0      0.1
# 9   9   2      0      0.1

# %%
from sklearn.tree import DecisionTreeClassifier
dt1=DecisionTreeClassifier(max_depth=1)#decision stump

# %%
X=df.iloc[:,0:2].values
y=df.iloc[:,2].values

# %%
dt1.fit(X,y)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
from sklearn.tree import plot_tree
plot_tree(dt1)
# Out:
# [Text(0.5, 0.75, 'x[0] <= 2.5\ngini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'gini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.625, 0.5, '  False')]

# %%
plot_decision_regions(X,y,clf=dt1,legend=2)
# Out:
# <Axes: >

# %%
df['y_pred']=dt1.predict(X)

# %%
df
# Out:
#    X1  X2  label  weights  y_pred
# 0   1   5      1      0.1       1
# 1   2   3      1      0.1       1
# 2   3   6      0      0.1       0
# 3   4   8      1      0.1       0
# 4   5   1      0      0.1       0
# 5   6   9      1      0.1       0
# 6   6   5      0      0.1       0
# 7   7   8      1      0.1       0
# 8   9   9      0      0.1       0
# 9   9   2      0      0.1       0

# %%
#total 3 mistake 3(0.1)=0.3 =error put in formula and get aplha
def calculate_model_weight(error):
    return 0.5*np.log((1-error)/(error+0.0000001))



# def update_row_weights(row,alpha=0.423):
#     #correct less increase
#     if row['label']==row['y_pred']:
#         return row['weights']*np.exp(-alpha)
#     else:
#         return row['weights']*np.exp(alpha)



# def create_new_dataset(df):
#     indices=[]
#     for i in range(df.shape[0]):
#         a=np.random.random()#this genrates 0 ≤ a < 1
#         for index,row in df.iterrows():
#             if row['cumsum_upper']>a and a>row['cumsum_lower']:
#                 indices.append(index)
#     return indices

# %%
alpha1=calculate_model_weight(0.3)

# %%
alpha1
# Out:
# np.float64(0.42364893019360184)

# %%
#update weights
def update_row_weights(row,alpha=0.423):
    #correct less increase
    if row['label']==row['y_pred']:
        return row['weights']*np.exp(-alpha)
    else:
        return row['weights']*np.exp(alpha)

# %%
df['updated_weights']=df.apply(update_row_weights,axis=1)

# %%
df
# Out:
#    X1  X2  label  weights  y_pred  updated_weights
# 0   1   5      1      0.1       1         0.065508
# 1   2   3      1      0.1       1         0.065508
# 2   3   6      0      0.1       0         0.065508
# 3   4   8      1      0.1       0         0.152653
# 4   5   1      0      0.1       0         0.065508
# 5   6   9      1      0.1       0         0.152653
# 6   6   5      0      0.1       0         0.065508
# 7   7   8      1      0.1       0         0.152653
# 8   9   9      0      0.1       0         0.065508
# 9   9   2      0      0.1       0         0.065508

# %%
df['updated_weights'].sum()
# Out:
# np.float64(0.9165153319682015)

# %%
df['normalized_weights']=df['updated_weights']/df['updated_weights'].sum()

# %%
df
# Out:
#    X1  X2  label  weights  y_pred  updated_weights  normalized_weights
# 0   1   5      1      0.1       1         0.065508            0.071475
# 1   2   3      1      0.1       1         0.065508            0.071475
# 2   3   6      0      0.1       0         0.065508            0.071475
# 3   4   8      1      0.1       0         0.152653            0.166559
# 4   5   1      0      0.1       0         0.065508            0.071475
# 5   6   9      1      0.1       0         0.152653            0.166559
# 6   6   5      0      0.1       0         0.065508            0.071475
# 7   7   8      1      0.1       0         0.152653            0.166559
# 8   9   9      0      0.1       0         0.065508            0.071475
# 9   9   2      0      0.1       0         0.065508            0.071475

# %%
df['normalized_weights'].sum()
# Out:
# np.float64(1.0)

# %%
df['cumsum_upper']=np.cumsum(df['normalized_weights'])

# %%
df
# Out:
#    X1  X2  label  weights  y_pred  updated_weights  normalized_weights  \
# 0   1   5      1      0.1       1         0.065508            0.071475
# 1   2   3      1      0.1       1         0.065508            0.071475
# 2   3   6      0      0.1       0         0.065508            0.071475
# 3   4   8      1      0.1       0         0.152653            0.166559
# 4   5   1      0      0.1       0         0.065508            0.071475
# 5   6   9      1      0.1       0         0.152653            0.166559
# 6   6   5      0      0.1       0         0.065508            0.071475
# 7   7   8      1      0.1       0         0.152653            0.166559
# 8   9   9      0      0.1       0         0.065508            0.071475
# 9   9   2      0      0.1       0         0.065508            0.071475
#
#    cumsum_upper
# 0      0.071475
# 1      0.142950
# 2      0.214425
# 3      0.380983
# 4      0.452458
# 5      0.619017
# 6      0.690492
# 7      0.857050
# 8      0.928525
# ...

# %%
df['cumsum_lower']=df['cumsum_upper']-df['normalized_weights']

# %%
df
# Out:
#    X1  X2  label  weights  y_pred  updated_weights  normalized_weights  \
# 0   1   5      1      0.1       1         0.065508            0.071475
# 1   2   3      1      0.1       1         0.065508            0.071475
# 2   3   6      0      0.1       0         0.065508            0.071475
# 3   4   8      1      0.1       0         0.152653            0.166559
# 4   5   1      0      0.1       0         0.065508            0.071475
# 5   6   9      1      0.1       0         0.152653            0.166559
# 6   6   5      0      0.1       0         0.065508            0.071475
# 7   7   8      1      0.1       0         0.152653            0.166559
# 8   9   9      0      0.1       0         0.065508            0.071475
# 9   9   2      0      0.1       0         0.065508            0.071475
#
#    cumsum_upper  cumsum_lower
# 0      0.071475      0.000000
# 1      0.142950      0.071475
# 2      0.214425      0.142950
# 3      0.380983      0.214425
# 4      0.452458      0.380983
# ...

# %%
#creating new data set by picking random samples
def create_new_dataset(df):
    indices=[]
    for i in range(df.shape[0]):
        a=np.random.random()#this genrates 0 ≤ a < 1
        for index,row in df.iterrows():
            if row['cumsum_upper']>a and a>row['cumsum_lower']:
                indices.append(index)
    return indices


# ✅ What is df.iterrows() ?

# iterrows() is a pandas function that:

# 👉 Iterates (loops) through each row of the DataFrame
# 👉 Returns two things for each row:

# (index, row_data)

# %%
index_values=create_new_dataset(df)

# %%
index_values
# Out:
# [0, 8, 7, 7, 7, 1, 9, 9, 5, 5]

# %%
second_df=df.iloc[index_values,0:4]

# %%
second_df
# Out:
#    X1  X2  label  weights
# 0   1   5      1      0.1
# 8   9   9      0      0.1
# 7   7   8      1      0.1
# 7   7   8      1      0.1
# 7   7   8      1      0.1
# 1   2   3      1      0.1
# 9   9   2      0      0.1
# 9   9   2      0      0.1
# 5   6   9      1      0.1
# 5   6   9      1      0.1

# %%
dt2=DecisionTreeClassifier(max_depth=1)

# %%
X=second_df.iloc[:,0:2].values
y=second_df.iloc[:,2].values

# %%
dt2.fit(X,y)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
plot_tree(dt2)
# Out:
# [Text(0.5, 0.75, 'x[0] <= 8.0\ngini = 0.42\nsamples = 10\nvalue = [3, 7]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.625, 0.5, '  False')]

# %%
plot_decision_regions(X,y,clf=dt2,legend=2)
# Out:
# <Axes: >

# %%
second_df['y_pred']=dt2.predict(X)

# %%
second_df
# Out:
#    X1  X2  label  weights  y_pred
# 0   1   5      1      0.1       1
# 8   9   9      0      0.1       0
# 7   7   8      1      0.1       1
# 7   7   8      1      0.1       1
# 7   7   8      1      0.1       1
# 1   2   3      1      0.1       1
# 9   9   2      0      0.1       0
# 9   9   2      0      0.1       0
# 5   6   9      1      0.1       1
# 5   6   9      1      0.1       1

# %%
alpha2=calculate_model_weight(0)

# %%
# def calculate_model_weight(error):
#     return 0.5*np.log((1-error)/(error+0.0000001))



# def update_row_weights(row,alpha=0.423):
#     #correct less increase
#     if row['label']==row['y_pred']:
#         return row['weights']*np.exp(-alpha)
#     else:
#         return row['weights']*np.exp(alpha)



# def create_new_dataset(df):
#     indices=[]
#     for i in range(df.shape[0]):
#         a=np.random.random()#this genrates 0 ≤ a < 1
#         for index,row in df.iterrows():
#             if row['cumsum_upper']>a and a>row['cumsum_lower']:
#                 indices.append(index)
#     return indices

# %%
alpha2
# Out:
# np.float64(8.05904782547916)

# %%
def update_row_weights(row,alpha=8.059):
    #correct less increase
    if row['label']==row['y_pred']:
        return row['weights']*np.exp(-alpha)
    else:
        return row['weights']*np.exp(alpha)

# %%
second_df['update_weights']=second_df.apply(update_row_weights,axis=1)

# %%
second_df
# Out:
#    X1  X2  label  weights  y_pred  update_weights
# 0   1   5      1      0.1       1        0.000032
# 8   9   9      0      0.1       0        0.000032
# 7   7   8      1      0.1       1        0.000032
# 7   7   8      1      0.1       1        0.000032
# 7   7   8      1      0.1       1        0.000032
# 1   2   3      1      0.1       1        0.000032
# 9   9   2      0      0.1       0        0.000032
# 9   9   2      0      0.1       0        0.000032
# 5   6   9      1      0.1       1        0.000032
# 5   6   9      1      0.1       1        0.000032

# %%
second_df['normalized_weights']=second_df['update_weights']/second_df['update_weights'].sum()

# %%
second_df
# Out:
#    X1  X2  label  weights  y_pred  update_weights  normalized_weights
# 0   1   5      1      0.1       1        0.000032                 0.1
# 8   9   9      0      0.1       0        0.000032                 0.1
# 7   7   8      1      0.1       1        0.000032                 0.1
# 7   7   8      1      0.1       1        0.000032                 0.1
# 7   7   8      1      0.1       1        0.000032                 0.1
# 1   2   3      1      0.1       1        0.000032                 0.1
# 9   9   2      0      0.1       0        0.000032                 0.1
# 9   9   2      0      0.1       0        0.000032                 0.1
# 5   6   9      1      0.1       1        0.000032                 0.1
# 5   6   9      1      0.1       1        0.000032                 0.1

# %%
second_df['normalized_weights'].sum()
# Out:
# np.float64(1.0000000000000002)

# %%
second_df['cumsum_upper']=np.cumsum(second_df['normalized_weights'])

# %%
second_df['cumsum_lower']=second_df['cumsum_upper']-second_df['normalized_weights']

# %%
df
# Out:
#    X1  X2  label  weights  y_pred  updated_weights  normalized_weights  \
# 0   1   5      1      0.1       1         0.065508            0.071475
# 1   2   3      1      0.1       1         0.065508            0.071475
# 2   3   6      0      0.1       0         0.065508            0.071475
# 3   4   8      1      0.1       0         0.152653            0.166559
# 4   5   1      0      0.1       0         0.065508            0.071475
# 5   6   9      1      0.1       0         0.152653            0.166559
# 6   6   5      0      0.1       0         0.065508            0.071475
# 7   7   8      1      0.1       0         0.152653            0.166559
# 8   9   9      0      0.1       0         0.065508            0.071475
# 9   9   2      0      0.1       0         0.065508            0.071475
#
#    cumsum_upper  cumsum_lower
# 0      0.071475      0.000000
# 1      0.142950      0.071475
# 2      0.214425      0.142950
# 3      0.380983      0.214425
# 4      0.452458      0.380983
# ...

# %%
index_values=create_new_dataset(second_df)

# %%
third_df=second_df.iloc[index_values,[0,1,2,3]]

# %%
third_df
# Out:
#    X1  X2  label  weights
# 9   9   2      0      0.1
# 9   9   2      0      0.1
# 5   6   9      1      0.1
# 1   2   3      1      0.1
# 1   2   3      1      0.1
# 5   6   9      1      0.1
# 1   2   3      1      0.1
# 9   9   2      0      0.1
# 1   2   3      1      0.1
# 8   9   9      0      0.1

# %%
dt3=DecisionTreeClassifier(max_depth=1)

# %%
X=third_df.iloc[:,0:2].values
y=third_df.iloc[:,2].values

# %%
dt3.fit(X,y)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
plot_tree(dt3)
# Out:
# [Text(0.5, 0.75, 'x[0] <= 7.5\ngini = 0.48\nsamples = 10\nvalue = [4, 6]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.625, 0.5, '  False')]

# %%
plot_decision_regions(X,y,clf=dt3,legend=2)
# Out:
# <Axes: >

# %%
third_df['y_pred']=dt3.predict(X)

# %%
third_df
# Out:
#    X1  X2  label  weights  y_pred
# 9   9   2      0      0.1       0
# 9   9   2      0      0.1       0
# 5   6   9      1      0.1       1
# 1   2   3      1      0.1       1
# 1   2   3      1      0.1       1
# 5   6   9      1      0.1       1
# 1   2   3      1      0.1       1
# 9   9   2      0      0.1       0
# 1   2   3      1      0.1       1
# 8   9   9      0      0.1       0

# %%
alpha3=calculate_model_weight(0)

# %%
alpha3
# Out:
# np.float64(8.05904782547916)

# %%
def update_row_weights(row,alpha=8.059):
    #correct less increase
    if row['label']==row['y_pred']:
        return row['weights']*np.exp(-alpha)
    else:
        return row['weights']*np.exp(alpha)

# %%
third_df['uptaded_weights']=third_df.apply(update_row_weights,axis=1)

# %%
third_df
# Out:
#    X1  X2  label  weights  y_pred  uptaded_weights
# 9   9   2      0      0.1       0         0.000032
# 9   9   2      0      0.1       0         0.000032
# 5   6   9      1      0.1       1         0.000032
# 1   2   3      1      0.1       1         0.000032
# 1   2   3      1      0.1       1         0.000032
# 5   6   9      1      0.1       1         0.000032
# 1   2   3      1      0.1       1         0.000032
# 9   9   2      0      0.1       0         0.000032
# 1   2   3      1      0.1       1         0.000032
# 8   9   9      0      0.1       0         0.000032

# %%
third_df['normalized_weights']=third_df['uptaded_weights']/third_df['uptaded_weights'].sum()

# %%
third_df['normalized_weights'].sum()
# Out:
# np.float64(1.0000000000000002)

# %%
third_df
# Out:
#    X1  X2  label  weights  y_pred  uptaded_weights  normalized_weights
# 9   9   2      0      0.1       0         0.000032                 0.1
# 9   9   2      0      0.1       0         0.000032                 0.1
# 5   6   9      1      0.1       1         0.000032                 0.1
# 1   2   3      1      0.1       1         0.000032                 0.1
# 1   2   3      1      0.1       1         0.000032                 0.1
# 5   6   9      1      0.1       1         0.000032                 0.1
# 1   2   3      1      0.1       1         0.000032                 0.1
# 9   9   2      0      0.1       0         0.000032                 0.1
# 1   2   3      1      0.1       1         0.000032                 0.1
# 8   9   9      0      0.1       0         0.000032                 0.1

# %%
third_df['cumsum_upper']=np.cumsum(third_df['normalized_weights'])

# %%
third_df['cumsum_lower']=third_df['cumsum_upper']-third_df['normalized_weights']

# %%
df
# Out:
#    X1  X2  label  weights  y_pred  updated_weights  normalized_weights  \
# 0   1   5      1      0.1       1         0.065508            0.071475
# 1   2   3      1      0.1       1         0.065508            0.071475
# 2   3   6      0      0.1       0         0.065508            0.071475
# 3   4   8      1      0.1       0         0.152653            0.166559
# 4   5   1      0      0.1       0         0.065508            0.071475
# 5   6   9      1      0.1       0         0.152653            0.166559
# 6   6   5      0      0.1       0         0.065508            0.071475
# 7   7   8      1      0.1       0         0.152653            0.166559
# 8   9   9      0      0.1       0         0.065508            0.071475
# 9   9   2      0      0.1       0         0.065508            0.071475
#
#    cumsum_upper  cumsum_lower
# 0      0.071475      0.000000
# 1      0.142950      0.071475
# 2      0.214425      0.142950
# 3      0.380983      0.214425
# 4      0.452458      0.380983
# ...

# %%
query=np.array([1,5]).reshape(1,2)
dt1.predict(query)
# Out:
# array([1])

# %%
dt2.predict(query)
# Out:
# array([1])

# %%
dt3.predict(query)
# Out:
# array([1])

# %%
alpha1*1+alpha2*1+alpha3*1
# Out:
# np.float64(16.541744581151924)

# %%
np.sign(16.54)
# Out:
# np.float64(1.0)

# %%
query=np.array([9,9]).reshape(1,2)

# %%
dt1.predict(query)
# Out:
# array([0])

# %%
dt2.predict(query)
# Out:
# array([0])

# %%
dt3.predict(query)
# Out:
# array([0])

# %%
alpha1*(-1)+alpha2*(-1)+alpha3*(-1)
# Out:
# np.float64(-16.541744581151924)

# %%
np.sign(-16.54)
# Out:
# np.float64(-1.0)

# %%
#use 1 for +1 and -1 for 0
